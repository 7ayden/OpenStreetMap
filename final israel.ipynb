# %%
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import pprint

def count_tags(filename):
        tags={}
        for action,elem in ET.iterparse(filename):
            if elem.tag in tags:
                tags[elem.tag]=tags[elem.tag]+1
            else:
                tags[elem.tag]=1
            elem.clear()
        return tags

pprint.pprint(count_tags('jerusalem_israel.osm'))
# Out:
# {'bounds': 1,
#  'member': 3881,
#  'nd': 716073,
#  'node': 645370,
#  'osm': 1,
#  'relation': 535,
#  'tag': 177384,
#  'way': 65316}

# %%
import xml.etree.ElementTree as ET
import pprint
import re


#defining regular expressions for quality check
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

#going through tag and check against RegEx
def key_type(element, keys):
    if element.tag == "tag":
        value = element.attrib['k']
        if re.search(problemchars,value):
            keys['problemchars']=keys['problemchars']+1
        elif re.search(lower_colon,value):
            keys['lower_colon']=keys['lower_colon']+1
        elif re.search(lower,value):
            keys['lower']=keys['lower']+1
        else:
            keys['other']=keys['other']+1
        pass
        
    return keys



def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

print process_map('jerusalem_israel.osm')
# Out:
# {'problemchars': 1, 'lower': 120538, 'other': 13502, 'lower_colon': 43343}

# %%
import xml.etree.ElementTree as ET
import pprint
import re


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])

    return users
users = process_map('jerusalem_israel.osm')
print len(users), "users in osm file in total"
# Out:
# 513 users in osm file in total

# %%
def find_elem_kval(kvals_to_inspect):    
    context = ET.iterparse('jerusalem_israel.osm', events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in ('node', 'way', 'relation'):
            for tag in elem.findall("tag"):
                if (tag.get("k") in kvals_to_inspect):
                    print elem.tag+" id:"+elem.attrib["id"]
                    for tag in elem.findall("tag"):
                        print "\t"+tag.tag+": k="+tag.get("k"), "v="+tag.get("v")
                    print "***********************************************"
            root.clear()

find_elem_kval(["FIXME"])
print ""
find_elem_kval(["addr:street2","addr2:street"])
print ""
find_elem_kval(["name:be-tarask"])
# Out:
# node id:1464782839
# 	tag: k=name v=חיל האוויר
# 	tag: k=tram v=yes
# 	tag: k=FIXME v=platform missing
# 	tag: k=railway v=tram_stop
# 	tag: k=public_transport v=stop_position
# ***********************************************
# node id:1464782855
# 	tag: k=name v=סיירת דוכיפת
# 	tag: k=tram v=yes
# 	tag: k=FIXME v=platform missing
# 	tag: k=railway v=tram_stop
# 	tag: k=public_transport v=stop_position
# ***********************************************
# node id:2146431599
# 	tag: k=name v=חיל האוויר
# 	tag: k=tram v=yes
# 	tag: k=FIXME v=platform missing
# 	tag: k=railway v=tram_stop
# 	tag: k=public_transport v=stop_position
# ***********************************************
# node id:2146431600
# 	tag: k=name v=סיירת דוכיפת
# 	tag: k=tram v=yes
# 	tag: k=FIXME v=platform missing
# 	tag: k=railway v=tram_stop
# 	tag: k=public_transport v=stop_position
# ***********************************************
# way id:253527105
# 	tag: k=name v=מנזר האחיות ציון
# 	tag: k=FIXME v=check religion
# 	tag: k=amenity v=place_of_worship
# 	tag: k=name:en v=Notre Dam de Sion
# 	tag: k=name:ro v=Mănăstirea Surorilor Notre-Dame de Sion (Catolică)
# 	tag: k=religion v=christian
# ***********************************************
#
#
# node id:29090735
# 	tag: k=name v=ירושלים
# 	tag: k=place v=city
# 	tag: k=capital v=yes
# 	tag: k=name:am v=እየሩሳሌም
# 	tag: k=name:an v=Cherusalem
# 	tag: k=name:ar v=أورشليم
# 	tag: k=name:az v=Jerusalem
# 	tag: k=name:be v=Іерусалім
# 	tag: k=name:bg v=Йерусалим
# 	tag: k=name:bn v=জেরুসালেম
# 	tag: k=name:bo v=ཇེ་རུ་ས་ལེམ།
# 	tag: k=name:br v=Jeruzalem
# 	tag: k=name:cs v=Jeruzalém
# 	tag: k=name:cu v=Їєроусалимъ
# 	tag: k=name:cv v=Иерусалим
# 	tag: k=name:cy v=Jeriwsalem
# 	tag: k=name:da v=Jerusalem
# 	tag: k=name:de v=Jerusalem
# 	tag: k=name:dv v=ޤުދުސް
# 	tag: k=name:el v=Ιερουσαλήμ
# 	tag: k=name:en v=Jerusalem
# 	tag: k=name:eo v=Jerusalemo
# 	tag: k=name:es v=Jerusalén
# 	tag: k=name:et v=Jeruusalemm
# 	tag: k=name:fa v=اورشلیم
# 	tag: k=name:fi v=Jerusalem
# 	tag: k=name:fj v=Jerusalemi
# 	tag: k=name:fo v=Jerúsalem
# 	tag: k=name:fr v=Jérusalem
# 	tag: k=name:fy v=Jeruzalim
# 	tag: k=name:ga v=Iarúsailéim
# 	tag: k=name:gd v=Ierusalem
# 	tag: k=name:gl v=Xerusalén
# 	tag: k=name:gn v=Herusalẽ
# 	tag: k=name:he v=ירושלים
# 	tag: k=name:hi v=यरुशलम
# 	tag: k=name:hr v=Jeruzalem
# 	tag: k=name:hu v=Jeruzsálem
# 	tag: k=name:hy v=Երուսաղեմ
# 	tag: k=name:id v=Yerusalem
# 	tag: k=name:io v=Ierusalem
# 	tag: k=name:is v=Jerúsalem
# 	tag: k=name:it v=Gerusalemme
# 	tag: k=name:ja v=エルサレム
# 	tag: k=name:jv v=Yérusalem
# 	tag: k=name:ka v=იერუსალიმი
# 	tag: k=name:kk v=Әл-Құдыс
# 	tag: k=name:kn v=ಜೆರುಸಲೆಂ
# 	tag: k=name:ko v=예루살렘
# 	tag: k=name:ku v=Orşelîm
# 	tag: k=name:kv v=Иерусалим
# 	tag: k=name:la v=Hierosolyma
# 	tag: k=name:li v=Jeruzalem
# 	tag: k=name:ln v=Yerusalémi
# 	tag: k=name:lt v=Jeruzalė
# 	tag: k=name:lv v=Jeruzāleme
# 	tag: k=name:mk v=Ерусалим
# 	tag: k=name:ml v=ജെറുസലേം
# 	tag: k=name:mn v=Иерусалим
# 	tag: k=name:mr v=जेरुसलेम
# 	tag: k=name:ms v=Baitulmuqaddis
# 	tag: k=name:my v=ဂျေရုဆလင်မြို့
# 	tag: k=name:nl v=Jeruzalem
# 	tag: k=name:oc v=Jerusalèm
# 	tag: k=name:os v=Иерусалим
# 	tag: k=name:pl v=Jerozolima
# 	tag: k=name:ps v=بيت المقدس
# 	tag: k=name:pt v=Jerusalém
# 	tag: k=name:qu v=Yerushalayim
# 	tag: k=name:ro v=Ierusalim
# 	tag: k=name:ru v=Иерусалим
# 	tag: k=name:rw v=Yerusalemu
# 	tag: k=name:sc v=Gerusalemme
# 	tag: k=name:sh v=Jeruzalem
# 	tag: k=name:sk v=Jeruzalem
# 	tag: k=name:sl v=Jeruzalem
# 	tag: k=name:sm v=Ierusalema
# 	tag: k=name:so v=Qudus
# 	tag: k=name:sq v=Jeruzalemi
# 	tag: k=name:sr v=Јерусалим
# 	tag: k=name:su v=Yerusalem
# 	tag: k=name:sv v=Jerusalem
# 	tag: k=name:sw v=Yerusalemu
# 	tag: k=name:ta v=யெரூசலம்
# 	tag: k=name:te v=జెరూసలేం
# 	tag: k=name:tg v=Уршалим
# 	tag: k=name:th v=เยรูซาเลม
# 	tag: k=name:tk v=Iýerusalim
# 	tag: k=name:tl v=Herusalem
# 	tag: k=name:tr v=Kudüs
# 	tag: k=name:tt v=Иерусалим
# 	tag: k=name:ug v=يېرۇسالېم
# 	tag: k=name:uk v=Єрусалим
# 	tag: k=name:ur v=بیت المقدس
# 	tag: k=name:uz v=Quddus
# 	tag: k=name:vi v=Jerusalem
# 	tag: k=name:vo v=Hierusalem
# 	tag: k=name:wa v=Djeruzalem
# 	tag: k=name:yi v=ירושלים
# 	tag: k=name:yo v=Jerúsálẹ́mù
# 	tag: k=name:zh v=耶路撒冷
# 	tag: k=int_name v=Jerusalem
# 	tag: k=name:ang v=Ierusalem
# 	tag: k=name:arc v=ܐܘܪܫܠܡ
# 	tag: k=name:arz v=القدس
# 	tag: k=name:ast v=Xerusalén
# 	tag: k=name:bjn v=Baitul Maqdis
# 	tag: k=name:ceb v=Jerusalen
# 	tag: k=name:ckb v=ئۆرشەلیم
# 	tag: k=name:crh v=Jerusalem
# 	tag: k=name:csb v=Jerozolëma
# 	tag: k=name:diq v=Urşelim
# 	tag: k=name:dsb v=Jeruzalem
# 	tag: k=name:ext v=Jerusalén
# 	tag: k=name:gan v=耶路撒冷
# 	tag: k=name:hak v=Yâ-lu-sat-lâng
# 	tag: k=name:he1 v=יְרוּשָׁלַיִם
# 	tag: k=name:hsb v=Jeruzalem
# 	tag: k=name:ilo v=Herusalem
# 	tag: k=name:kaa v=Jerusalem
# 	tag: k=name:kab v=Orcalim
# 	tag: k=name:lad v=Yerushalayim
# 	tag: k=name:lez v=Иерусалим
# 	tag: k=name:lij v=Gerusalemme
# 	tag: k=name:lmo v=Gerüsalem
# 	tag: k=name:mdf v=Ерусалим
# 	tag: k=name:mhr v=Иерусалим
# 	tag: k=name:mwl v=Jarusalen
# 	tag: k=name:nah v=Ierusalem
# 	tag: k=name:nrm v=Jérusalem
# 	tag: k=name:pap v=Herusalem
# 	tag: k=name:pnb v=یروشلم
# 	tag: k=name:rue v=Єрусалим
# 	tag: k=name:sah v=Иерусалим
# 	tag: k=name:scn v=Girusalemmi
# 	tag: k=name:tpi v=Yerusalem
# 	tag: k=name:vec v=Hierusalem
# 	tag: k=name:vep v=Jerusalim
# 	tag: k=name:zea v=Jeruzalem
# 	tag: k=capital_1 v=yes
# 	tag: k=wikipedia v=en:Jerusalem
# 	tag: k=is_capital v=country
# 	tag: k=population v=780200
# 	tag: k=admin_level v=2
# 	tag: k=alt_name:is v=Jórsalir;Jórsalaborg
# 	tag: k=alt_name:vi v=Giêrusalem
# 	tag: k=name:zh-yue v=耶路撒冷
# 	tag: k=name:bat-smg v=Jerozalė
# 	tag: k=name:fiu-vro v=Jeruusalemm
# 	tag: k=is_in:country v=Israel
# 	tag: k=name:roa-tara v=Gerusalemme
# 	tag: k=name:be-tarask v=Ерусалім
# 	tag: k=is_in:continent v=Asia
# 	tag: k=name:zh-min-nan v=Iâ-lō͘-sat-léng
# 	tag: k=capital_ISO3166-1 v=yes
# 	tag: k=is_in:country_code v=IL
# ***********************************************
# relation id:1473946
# 	tag: k=flag v=http://upload.wikimedia.org/wikipedia/commons/d/d4/Flag_of_Israel.svg
# 	tag: k=name v=מדינת ישראל
# 	tag: k=type v=boundary
# 	tag: k=name:af v=Israel
# 	tag: k=name:am v=እስራኤል
# 	tag: k=name:an v=Israel
# 	tag: k=name:ar v=إسرائيل
# 	tag: k=name:av v=Гlизраил
# 	tag: k=name:az v=İsrail
# 	tag: k=name:ba v=Израиль
# 	tag: k=name:be v=Ізраіль
# 	tag: k=name:bg v=Израел
# 	tag: k=name:bm v=Israil
# 	tag: k=name:bn v=ইসরায়েল
# 	tag: k=name:bo v=ཨི་སི་ར་ཨེལ།
# 	tag: k=name:br v=Israel
# 	tag: k=name:bs v=Izrael
# 	tag: k=name:ca v=Israel
# 	tag: k=name:ce v=Израиль
# 	tag: k=name:co v=Israele
# 	tag: k=name:cs v=Izrael
# 	tag: k=name:cu v=Їꙁдраил҄ь
# 	tag: k=name:cv v=Израиль
# 	tag: k=name:cy v=Israel
# 	tag: k=name:da v=Israel
# 	tag: k=name:de v=Israel
# 	tag: k=name:dv v=އިސްރާއީލު
# 	tag: k=name:dz v=ཨིཛ་རཱེལ་
# 	tag: k=name:el v=Ισραήλ
# 	tag: k=name:en v=Israel
# 	tag: k=name:eo v=Israelo
# 	tag: k=name:es v=Israel
# 	tag: k=name:et v=Iisrael
# 	tag: k=name:eu v=Israel
# 	tag: k=name:fa v=فلسطین اشغالی
# 	tag: k=name:fi v=Israel
# 	tag: k=name:fj v=Isireli
# 	tag: k=name:fo v=Ísrael
# 	tag: k=name:fr v=Israël
# 	tag: k=name:fy v=Israel
# 	tag: k=name:ga v=Iosrael
# 	tag: k=name:gd v=Iosrael
# 	tag: k=name:gl v=Israel
# 	tag: k=name:gn v=Israel
# 	tag: k=name:gu v=ઈઝરાયલ
# 	tag: k=name:gv v=Israel
# 	tag: k=name:ha v=Isra'ila
# 	tag: k=name:he v=ישראל
# 	tag: k=name:hi v=इज़राइल
# 	tag: k=name:hr v=Izrael
# 	tag: k=name:ht v=Izrayèl
# 	tag: k=name:hu v=Izrael
# 	tag: k=name:hy v=Իսրայել
# 	tag: k=name:ia v=Israel
# 	tag: k=name:id v=Israel
# 	tag: k=name:ie v=Israel
# 	tag: k=name:ig v=Israel
# 	tag: k=name:io v=Israel
# 	tag: k=name:is v=Ísrael
# 	tag: k=name:it v=Israele
# 	tag: k=name:ja v=イスラエル
# 	tag: k=name:jv v=Israèl
# 	tag: k=name:ka v=ისრაელი
# 	tag: k=name:kg v=Israel
# 	tag: k=name:kk v=Израиль
# 	tag: k=name:kl v=Israel
# 	tag: k=name:kn v=ಇಸ್ರೇಲ್
# 	tag: k=name:ko v=이스라엘
# 	tag: k=name:ku v=Îsrael
# 	tag: k=name:kv v=Израиль
# 	tag: k=name:kw v=Ysrael
# 	tag: k=name:ky v=Израиль
# 	tag: k=name:la v=Israel
# 	tag: k=name:lb v=Israel
# 	tag: k=name:li v=Israël
# 	tag: k=name:ln v=Israel
# 	tag: k=name:lt v=Izraelis
# 	tag: k=name:lv v=Izraēla
# 	tag: k=name:mk v=Израел
# 	tag: k=name:ml v=ഇസ്രയേൽ
# 	tag: k=name:mn v=Израйль
# 	tag: k=name:mr v=इस्रायल
# 	tag: k=name:ms v=Israel
# 	tag: k=name:mt v=Iżrael
# 	tag: k=name:my v=အစ္စရေးနိုင်ငံ
# 	tag: k=name:na v=Iteraer
# 	tag: k=name:ne v=इजरायल
# 	tag: k=name:nl v=Israël
# 	tag: k=name:nn v=Israel
# 	tag: k=name:no v=Israel
# 	tag: k=name:nv v=Ízrel Bikéyah
# 	tag: k=name:oc v=Israèl
# 	tag: k=name:or v=ଇସ୍ରାଏଲ
# 	tag: k=name:os v=Израиль
# 	tag: k=name:pa v=ਇਜ਼ਰਾਇਲ
# 	tag: k=name:pl v=Izrael
# 	tag: k=name:ps v=اسرائيل
# 	tag: k=name:pt v=Israel
# 	tag: k=name:qu v=Israyil
# 	tag: k=name:ro v=Israel
# 	tag: k=name:ru v=Израиль
# 	tag: k=name:rw v=Isirayeli
# 	tag: k=name:sa v=इस्रेल
# 	tag: k=name:sc v=Israele
# 	tag: k=name:se v=Israel
# 	tag: k=name:sh v=Izrael
# 	tag: k=name:si v=ඊශ්‍රායලය
# 	tag: k=name:sk v=Izrael
# 	tag: k=name:sl v=Izrael
# 	tag: k=name:sm v=Israel
# 	tag: k=name:so v=Israaiil
# 	tag: k=name:sq v=Izraeli
# 	tag: k=name:sr v=Израел
# 	tag: k=name:ss v=Ka-Israyeli
# 	tag: k=name:sv v=Israel
# 	tag: k=name:sw v=Israel
# 	tag: k=name:ta v=இசுரேல்
# 	tag: k=name:te v=ఇజ్రాయిల్
# 	tag: k=name:tg v=Исроил
# 	tag: k=name:th v=ประเทศอิสราเอล
# 	tag: k=name:tk v=Ysraýyl
# 	tag: k=name:tl v=Israel
# 	tag: k=name:tr v=İsrail
# 	tag: k=name:tt v=Исраил
# 	tag: k=name:ug v=ئىسرائىلىيە
# 	tag: k=name:uk v=Ізраїль
# 	tag: k=name:ur v=اسرائیل
# 	tag: k=name:uz v=Isroil
# 	tag: k=name:vi v=Israel
# 	tag: k=name:vo v=Yisraelän
# 	tag: k=name:wa v=Israyel
# 	tag: k=name:wo v=Israayil
# 	tag: k=name:yi v=ישראל
# 	tag: k=name:yo v=Ísráẹ́lì
# 	tag: k=name:zh v=以色列
# 	tag: k=name:zu v=Isreyili
# 	tag: k=boundary v=administrative
# 	tag: k=int_name v=ישראל
# 	tag: k=name:ace v=Israel
# 	tag: k=name:als v=Israel
# 	tag: k=name:ang v=Israhēl
# 	tag: k=name:arc v=ܐܝܣܪܐܝܠ
# 	tag: k=name:arz v=اسرائيل
# 	tag: k=name:ast v=Israel
# 	tag: k=name:bar v=Israel
# 	tag: k=name:bcl v=Israel
# 	tag: k=name:bpy v=ইসরাইল
# 	tag: k=name:bxr v=Израиль
# 	tag: k=name:ceb v=Israel
# 	tag: k=name:ckb v=ئیسرائیل
# 	tag: k=name:crh v=İsrail
# 	tag: k=name:csb v=Izrael
# 	tag: k=name:diq v=İsrail
# 	tag: k=name:dsb v=Israel
# 	tag: k=name:ext v=Israel
# 	tag: k=name:frp v=Israyèl
# 	tag: k=name:frr v=Israel
# 	tag: k=name:gag v=İsrail
# 	tag: k=name:gan v=以色列
# 	tag: k=name:hak v=Yî-set-lie̍t
# 	tag: k=name:haw v=ʻIseraʻela
# 	tag: k=name:hif v=Israel
# 	tag: k=name:hsb v=Israel
# 	tag: k=name:ilo v=Israel
# 	tag: k=name:jbo v=brogu'e
# 	tag: k=name:kab v=Israyil
# 	tag: k=name:kbd v=Исраэл
# 	tag: k=name:koi v=Исраэль
# 	tag: k=name:ksh v=Israel
# 	tag: k=name:lad v=Medinat Yisrael
# 	tag: k=name:lez v=Израиль
# 	tag: k=name:lij v=Isræ
# 	tag: k=name:lmo v=Israel
# 	tag: k=name:mdf v=Израиль
# 	tag: k=name:mwl v=Eisrael
# 	tag: k=name:mzn v=اسرائیل
# 	tag: k=name:nah v=Israel
# 	tag: k=name:nap v=Israele
# 	tag: k=name:nds v=Israel
# 	tag: k=name:nov v=Israel
# 	tag: k=name:pam v=Israel
# 	tag: k=name:pap v=Israel
# 	tag: k=name:pih v=Esrail
# 	tag: k=name:pms v=Israel
# 	tag: k=name:pnb v=اسرائیل
# 	tag: k=name:pnt v=Ισραήλ
# 	tag: k=name:rmy v=Israel
# 	tag: k=name:rue v=Ізраіль
# 	tag: k=name:sah v=Исраил
# 	tag: k=name:scn v=Israeli
# 	tag: k=name:sco v=Israel
# 	tag: k=name:srn v=Israel
# 	tag: k=name:stq v=Israel
# 	tag: k=name:szl v=Izrael
# 	tag: k=name:tet v=Izraél
# 	tag: k=name:tpi v=Israel
# 	tag: k=name:tzl v=Israidia
# 	tag: k=name:udm v=Израиль
# 	tag: k=name:vec v=Israełe
# 	tag: k=name:vep v=Izrail'
# 	tag: k=name:war v=Israel
# 	tag: k=name:wuu v=以色列
# 	tag: k=name:xal v=Изралмудин Орн
# 	tag: k=name:xmf v=ისრაელი
# 	tag: k=name:zea v=Israël
# 	tag: k=timezone v=Asia/Jerusalem
# 	tag: k=wikidata v=Q801
# 	tag: k=ISO3166-1 v=IL
# 	tag: k=wikipedia v=en:Israel
# 	tag: k=admin_level v=2
# 	tag: k=alt_name:vi v=Ixraen;Do Thái
# 	tag: k=name:nds-nl v=Israël
# 	tag: k=name:simple v=Israel
# 	tag: k=name:zh-yue v=以色列
# 	tag: k=name:bat-smg v=Izraelis
# 	tag: k=name:fiu-vro v=Iisrael
# 	tag: k=name:roa-tara v=Israele
# 	tag: k=official_name v=מדינת ישראל;دولة إسرائيل
# 	tag: k=name:be-tarask v=Ізраіль
# 	tag: k=name:zh-min-nan v=Í-sek-lia̍t-kok
# 	tag: k=ISO3166-1:alpha2 v=IL
# 	tag: k=ISO3166-1:alpha3 v=ISR
# 	tag: k=official_name:en v=State of Israel
# 	tag: k=official_name:eo v=Ŝtato Israelo
# 	tag: k=official_name:fr v=État d’Israël
# 	tag: k=official_name:pl v=Państwo Izrael
# 	tag: k=official_name:ru v=Государство Израиль
# 	tag: k=ISO3166-1:numeric v=376
# ***********************************************

# %%
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import codecs
from collections import defaultdict
import re
import pprint

OSMFILE = 'jerusalem_israel.osm'
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons", "Lane"]
# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            'Rd.': 'Road',
            'Ave': 'Avenue',
            'Pkwy': 'Parkway',
            'Dr': 'Drive',
            'Dr.': 'Drive',
            'Exressway': 'Expressway',
            'Expessway': 'Expressway',
            'Trl': 'Trail',
            'Blvd': 'Boulevard',
            'Blvd.': 'Boulevard',
            }
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

# returns true if an element contains a street value
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


# function that reads osm file line by line and finds street names to audit
def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

# function to change incorrect street types to correct street types
def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = name.replace(street_type, mapping[street_type])

    return name


def test():
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types)) #print out dictonary of potentially incorrect street types

    for st_type, ways in st_types.iteritems():
        for name in ways:
            if street_type_re.search(name).group() in mapping:
                better_name = update_name(name, mapping)
                print name, "=>", better_name #print out street names that were changed

if __name__ == '__main__':
    test()
# Out:
# {'Agripas': set(['Agripas']),
#  'Al-Amid': set(['Umm Al-Amid']),
#  'Al-Bayan': set(['Al-Bayan']),
#  'Al-Masharif': set(['Al-Masharif']),
#  'Al-Mask': set(['Al-Mask']),
#  u'Aljoz': set([u'\u0646\u0647\u0627\u064a\u0629 \u0627\u0644\u0645\u0646\u0637\u0642\u0629 \u0627\u0644\u0635\u0646\u0627\u0639\u064a\u0629  ending of the Industrial zone Wadi Aljoz']),
#  'Anata': set(['Anata']),
#  'Anatot': set(['Anatot']),
#  'Bachar': set(['Nissim Bachar']),
#  'Bir-As-Sabil': set(['Bir-As-Sabil']),
#  'Botta': set(['Paul Emile Botta']),
#  u'Dolorosa': set([u'\u05d5\u05d9\u05d4 \u05d3\u05d5\u05dc\u05d5\u05e8\u05d5\u05d6\u05d4 - Via Dolorosa']),
#  'El-Sahel': set(['El-Sahel']),
#  'Hanina': set(['Beit Hanina']),
#  'Hatut': set(['Hatut']),
#  u'Het': set([u"\u05d4\u05e2'\u05d7 - HaAin Het"]),
#  'Hospital': set(['Located on Mt. Scopus Near Augusta Victoria Hospital']),
#  u'Israel': set([u'\u05e9\u05d1\u05d8\u05d9 \u05d9\u05e9\u05e8\u05d0\u05dc - Shivtei Israel']),
#  'Jabal': set(["Mu'adh Bin Jabal"]),
#  u'Joz': set([u'\u0628\u062f\u0627\u064a\u0629 \u0627\u0644\u0645\u0646\u0637\u0642\u0629 \u0627\u0644\u0635\u0646\u0627\u0639\u064a\u0629 (\u0648\u0627\u062f\u064a \u0627\u0644\u062c\u0648\u0632)  begining of the industrial zone Wadi al Joz']),
#  'Mall': set(['Mamila Mall']),
#  'Mamila': set(['Mamila']),
#  u'Mountain': set([u'\u0634\u0627\u0631\u0639 \u064a\u0624\u062f\u064a \u0625\u0644\u0649 \u062c\u0628\u0644 \u0627\u0644\u0631\u0648\u064a\u0633\u0627\u062a Street leads to Ruwaisat Mountain']),
#  'Rd.': set(['Hebron Rd.']),
#  'St': set(['Dorot Rishonim St']),
#  'St.': set(['Beit Hanina St.', "Hanevi'im St."]),
#  'Wakaleh': set(['Al Wakaleh']),
#  'Yafo': set(['Yafo']),
#  'al-Dur': set(['Shajarat al-Dur']),
#  'housing': set(['Al zahra housing']),
#  u'land': set([u'\u0637\u0631\u064a\u0642 \u064a\u0624\u062f\u064a \u0625\u0644\u0649 \u0627\u0644\u0623\u0631\u0627\u0636\u064a \u0627\u0644\u0632\u0631\u0627\u0639\u064a\u0629 Road leading to the agricultural land']),
#  'road': set(['Nablus road']),
#  u'school': set([u'\u0634\u0627\u0631\u0639 \u0641\u0631\u0639\u064a / \u0637\u0631\u064a\u0642 \u0645\u062e\u062a\u0635\u0631 \u0644\u0644\u0645\u062f\u0631\u0633\u0629 A side street / shortcut to the school']),
#  'st': set(['Azzahra st']),
#  'street': set(['al makhaniq street'])}
# Hanevi'im St. => Hanevi'im Street
# Beit Hanina St. => Beit Hanina Street
# Hebron Rd. => Hebron Road
# Dorot Rishonim St => Dorot Rishonim Street

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import pprint
import re
import codecs
import json
from pymongo import MongoClient


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

def is_address(elem):
    if elem.attrib['k'][:5] == "addr:":
        return True



def shape_element(element):
    node = {}

    if element.tag == "node" or element.tag == "way" :

      node['type'] = element.tag

      # Parse attributes
      for a in element.attrib:
        if a in CREATED:
          if 'created' not in node:
            node['created'] = {}
          node['created'][a] = element.attrib[a]

        elif a in ['lat', 'lon']:
          if 'pos' not in node:
            node['pos'] = [None, None]

          if a == 'lat':
            node['pos'][0] = float(element.attrib[a])
          else:
            node['pos'][1] = float(element.attrib[a])

        else:
          node[a] = element.attrib[a]

      # Iterate tag children
      for tag in element.iter("tag"):
        if not problemchars.search(tag.attrib['k']):
          # Tags with single colon
          if lower_colon.search(tag.attrib['k']):

            # Single colon beginning with addr
            if tag.attrib['k'].find('addr') == 0:
              if 'address' not in node:
                node['address'] = {}

              sub_attr = tag.attrib['k'].split(':', 1)
              node['address'][sub_attr[1]] = tag.attrib['v']

            # All other single colons processed normally
            else:
              node[tag.attrib['k']] = tag.attrib['v']

          # Tags with no colon
          elif tag.attrib['k'].find(':') == -1:
            node[tag.attrib['k']] = tag.attrib['v']

      # Iterate nd children
      for nd in element.iter("nd"):
        if 'node_refs' not in node:
          node['node_refs'] = []
        node['node_refs'].append(nd.attrib['ref'])

      return node
    else:
      return None


def process_map(file_in, pretty = False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def test():
    # NOTE: if you are running this code on your computer, with a larger dataset, 
    # call the process_map procedure with pretty=False. The pretty=True option adds 
    # additional spaces to the output, making it significantly larger.
    data = process_map('jerusalem_israel.osm', False)
    print len(data)
    pprint.pprint(data[10])
    pprint.pprint(data[-10])
    

if __name__ == "__main__":
    test()
# Out:
# 710686
# {'created': {'changeset': '22153763',
#              'timestamp': '2014-05-05T19:51:57Z',
#              'uid': '385027',
#              'user': 'Ori952',
#              'version': '5'},
#  'id': '29942465',
#  'pos': [31.7766745, 35.22721],
#  'type': 'node'}
# {'building': 'yes',
#  'created': {'changeset': '41795805',
#              'timestamp': '2016-08-30T09:52:18Z',
#              'uid': '189946',
#              'user': 'BMM994',
#              'version': '1'},
#  'id': '439863338',
#  'node_refs': ['4375400348',
#                '4375400293',
#                '4375400279',
#                '4375400264',
#                '4375400300',
#                '4375400262',
#                '4375400294',
#                '4375400254',
#                '4375400249',
#                '4375400263',
#                '4375400325',
#                '4375400353',
#                '4375400351',
#                '4375400329',
#                '4375400350',
#                '4375400276',
#                '4375400352',
#                '4375400290',
#                '4375400304',
#                '4375400336',
#                '4375400334',
#                '4375400330',
#                '4375400332',
#                '4375400348'],
#  'type': 'way'}

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import json
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017")
db = client.openstreetmap

def insert_json(infile, db):
    jsonfile=open(infile)
    for dic in jsonfile:
        data=json.loads(dic)
        db.maps.insert_one(data)
insert_json('jerusalem_israel.osm.json',db)

# %%
client = MongoClient('localhost:27017')
db = client.peru
collection = db.map_data

with open('jerusalem_israel.osm.json', 'r') as f:
    for row in f:
        data = json.loads(row)
        db.map_data.insert(data)
# Out:
# /Users/jaydenyuen/anaconda/envs/DAND/lib/python2.7/site-packages/ipykernel/__main__.py:8: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.

# %%
database_stats = db.command("dbstats")
userids = collection.distinct("created.uid")

# find number of elements associated with each user and outputs the latest timestamp associated with each user
user_contribution = collection.aggregate([{"$group": {"_id": "$created.user","entries": {"$sum":1}, "max":{"$max":"$created.timestamp"}}},
                      {"$sort": {"entries":-1}}])

# data for users that have contributed less than 10 elements to the data set
userslt10_contribution = collection.aggregate([{"$group": 
                                                    {"_id": "$created.user","entries": {"$sum":1}, 
                                                     "max":{"$max":"$created.timestamp"}}},
                      {"$match": {"entries":{"$lt":10}}},
                      {"$sort":{"max":-1}}])

# WAY AND NODE ELEMENT ANALYSIS
# outputs distinct element types in data set: only should output way and node
element_types = collection.distinct("type")

# total documents in the database
element_count = collection.count()

# counts number of elements created by year
timestamps = collection.aggregate([{"$group": {"_id": {"$substr": ["$created.timestamp", 0, 4]}, "count":{"$sum":1}}},
                                   {"$sort": {"_id":1}}])


# AMENITY ANALYSIS: SCHOOLS, CHURCHES, RESTAURANTS, ETC.
# list of all amenities included in the data base
distinct_amenity = collection.distinct("amenity")

# counts of entries for each amenity type
amenity_count = collection.aggregate([{"$match": {"amenity":{"$exists":1}}},
                      {"$group": {"_id": "$amenity", "count":{"$sum":1}}},
                      {"$sort": {"count":-1}}])

# %%
print database_stats
# Out:
# {u'storageSize': 51752960.0, u'ok': 1.0, u'avgObjSize': 235.21085542700996, u'views': 0, u'db': u'peru', u'indexes': 1, u'objects': 710686, u'collections': 1, u'numExtents': 0, u'dataSize': 167161062.0, u'indexSize': 6266880.0}

# %%
print(list(user_contribution))
# Out:
# [{u'max': u'2016-08-30T10:11:43Z', u'_id': u'BMM994', u'entries': 384228}, {u'max': u'2016-07-26T07:42:17Z', u'_id': u'ENSG Battir', u'entries': 147273}, {u'max': u'2011-06-27T17:45:06Z', u'_id': u'kkl_import', u'entries': 29721}, {u'max': u'2016-08-30T08:38:36Z', u'_id': u'valleyofdawn', u'entries': 21150}, {u'max': u'2016-08-24T21:02:53Z', u'_id': u'eric22', u'entries': 20118}, {u'max': u'2016-08-28T17:22:08Z', u'_id': u'zstadler', u'entries': 13281}, {u'max': u'2016-01-17T14:40:38Z', u'_id': u'GrassrootsJerusalem_GIS', u'entries': 11596}, {u'max': u'2016-07-27T08:37:56Z', u'_id': u'Mr Massri', u'entries': 8107}, {u'max': u'2009-07-02T20:48:14Z', u'_id': u'JumpStart International', u'entries': 7966}, {u'max': u'2016-07-13T17:37:14Z', u'_id': u'Mr_Israel', u'entries': 7030}, {u'max': u'2016-07-12T06:53:01Z', u'_id': u'WillRock41', u'entries': 4984}, {u'max': u'2016-08-06T14:07:57Z', u'_id': u'Ilanride22', u'entries': 3472}, {u'max': u'2016-01-30T18:50:59Z', u'_id': u'ualios', u'entries': 3455}, {u'max': u'2015-06-04T17:31:46Z', u'_id': u'yrtimiD', u'entries': 3451}, {u'max': u'2016-03-02T10:27:17Z', u'_id': u'HAMsandwich', u'entries': 3440}, {u'max': u'2016-08-21T18:23:10Z', u'_id': u'MSF-Fieldco', u'entries': 2693}, {u'max': u'2011-06-19T07:57:06Z', u'_id': u'tanask', u'entries': 2504}, {u'max': u'2011-07-13T18:32:28Z', u'_id': u'talkat', u'entries': 1970}, {u'max': u'2011-02-05T14:23:32Z', u'_id': u'Esperanza36', u'entries': 1947}, {u'max': u'2016-08-23T09:56:53Z', u'_id': u'sivan00', u'entries': 1921}, {u'max': u'2010-05-11T16:45:46Z', u'_id': u'EdoM', u'entries': 1679}, {u'max': u'2016-06-05T12:55:14Z', u'_id': u'Ori952', u'entries': 1524}, {u'max': u'2013-12-01T18:59:13Z', u'_id': u'xiaoweike', u'entries': 1370}, {u'max': u'2013-06-20T19:34:36Z', u'_id': u'adrukh', u'entries': 1211}, {u'max': u'2015-05-24T20:42:05Z', u'_id': u'Orot92', u'entries': 1175}, {u'max': u'2013-02-08T13:11:57Z', u'_id': u'dimka', u'entries': 1110}, {u'max': u'2015-06-13T11:09:35Z', u'_id': u'dekeleinidekel', u'entries': 1076}, {u'max': u'2010-04-13T19:55:36Z', u'_id': u'FireAphis', u'entries': 1036}, {u'max': u'2016-08-03T10:06:21Z', u'_id': u'Ynhockey', u'entries': 982}, {u'max': u'2015-10-13T09:52:27Z', u'_id': u'jlemguy', u'entries': 979}, {u'max': u'2015-07-12T11:01:50Z', u'_id': u'Israelmeirwi', u'entries': 870}, {u'max': u'2016-08-17T19:59:13Z', u'_id': u'\u0160lomo', u'entries': 673}, {u'max': u'2015-08-17T08:20:16Z', u'_id': u'sevapog', u'entries': 641}, {u'max': u'2016-02-13T07:15:25Z', u'_id': u'Il Maestro', u'entries': 588}, {u'max': u'2016-01-20T22:25:31Z', u'_id': u'SaraW', u'entries': 579}, {u'max': u'2016-05-15T12:28:53Z', u'_id': u'Ido Marom', u'entries': 566}, {u'max': u'2016-08-17T19:42:02Z', u'_id': u'Doron Yosha', u'entries': 515}, {u'max': u'2016-08-28T12:35:51Z', u'_id': u'Kostik', u'entries': 484}, {u'max': u'2011-07-23T13:26:34Z', u'_id': u'DoK', u'entries': 478}, {u'max': u'2012-09-27T23:23:45Z', u'_id': u'Svedmc', u'entries': 411}, {u'max': u'2016-06-20T14:45:51Z', u'_id': u'adi_z', u'entries': 408}, {u'max': u'2011-02-21T08:49:41Z', u'_id': u'haketem', u'entries': 403}, {u'max': u'2016-06-23T18:29:42Z', u'_id': u'hansemann1234', u'entries': 375}, {u'max': u'2014-03-22T22:17:07Z', u'_id': u'Commodore Hotel Jerusalem', u'entries': 364}, {u'max': u'2016-05-19T19:09:29Z', u'_id': u'Petsamo', u'entries': 328}, {u'max': u'2016-04-07T23:23:43Z', u'_id': u'Nodes&Roads', u'entries': 289}, {u'max': u'2015-09-09T16:35:44Z', u'_id': u'abel801', u'entries': 279}, {u'max': u'2016-03-28T07:42:06Z', u'_id': u'MoJ Maps', u'entries': 275}, {u'max': u'2013-06-22T19:24:40Z', u'_id': u'Vladimir Kondratiev', u'entries': 273}, {u'max': u'2016-06-17T13:43:52Z', u'_id': u'kabudi', u'entries': 259}, {u'max': u'2016-03-07T03:14:15Z', u'_id': u'raanan_t', u'entries': 254}, {u'max': u'2013-10-30T20:49:02Z', u'_id': u'Wizah', u'entries': 229}, {u'max': u'2012-03-10T16:04:26Z', u'_id': u'binawsome', u'entries': 228}, {u'max': u'2014-10-11T18:47:50Z' ...

# %%
print element_types
# Out:
# [u'node', u'palm', u'Waypoint', u'way', u'Old ecomuseum, Restaurant', u'Basic school for Boys', u'Boulangerie', u'Macon', u'Village Council Building', u'Electricien', u'Mason', u'Secondary School for Boys', u'Garage', u'Forgeron', u'Basic school for Girls', u'Cyber Cafe', u'0ld Mosque', u'Epicerie', u'Secondary school for Girls']

# %%
print element_count
# Out:
# 710686

# %%
print (list(timestamps))
# Out:
# [{u'count': 710, u'_id': u'2007'}, {u'count': 419, u'_id': u'2008'}, {u'count': 12236, u'_id': u'2009'}, {u'count': 4372, u'_id': u'2010'}, {u'count': 47366, u'_id': u'2011'}, {u'count': 65255, u'_id': u'2012'}, {u'count': 93660, u'_id': u'2013'}, {u'count': 183260, u'_id': u'2014'}, {u'count': 93935, u'_id': u'2015'}, {u'count': 209473, u'_id': u'2016'}]

# %%
print distinct_amenity
# Out:
# [u'place_of_worship', u'embassy', u'restaurant', u'atm', u'bus_station', u'fuel', u'police', u'bench', u'school', u'hospital', u'parking', u'toilets', u'kindergarten', u'post_office', u'public_building', u'bank', u'townhall', u'arts_centre', u'cafe', u'nightclub', u'car_rental', u'pharmacy', u'shop', u'library', u'doctors', u'college', u'car_wash', u'taxi', u'bureau_de_change', u'car_sharing', u'recycling', u'university', u'fire_station', u'theatre', u'fast_food', u'pub', u'telephone', u'grave_yard', u'post_box', u'cinema', u'studio', u'waste_basket', u'waste_disposal', u'fountain', u'courthouse', u'monastery', u"children's home", u'0', u'drinking_water', u'swimming_pool', u'bbq', u'dentist', u'youth_centre', u'driving_school', u'vending_machine', u'community_centre', u'NGO', u'clinic', u'bar', u'veterinary', u'marketplace', u'parking_entrance', u'social_facility', u'insitute', u'childcare', u'internet_cafe', u'social_centre', u'shelter', u'events_venue', u'Archive', u'amphitheater', u'retirement_home', u'ritual_bath', u'\u05e8\u05de\u05ea \u05d4\u05d7\u05d9\u05e0\u05d5\u05da', u'parking_space']

# %%
print (list(amenity_count))
# Out:
# [{u'count': 606, u'_id': u'school'}, {u'count': 566, u'_id': u'place_of_worship'}, {u'count': 457, u'_id': u'parking'}, {u'count': 132, u'_id': u'restaurant'}, {u'count': 81, u'_id': u'public_building'}, {u'count': 72, u'_id': u'fuel'}, {u'count': 66, u'_id': u'cafe'}, {u'count': 61, u'_id': u'doctors'}, {u'count': 61, u'_id': u'bank'}, {u'count': 58, u'_id': u'college'}, {u'count': 54, u'_id': u'hospital'}, {u'count': 48, u'_id': u'pharmacy'}, {u'count': 46, u'_id': u'drinking_water'}, {u'count': 45, u'_id': u'kindergarten'}, {u'count': 41, u'_id': u'toilets'}, {u'count': 41, u'_id': u'townhall'}, {u'count': 39, u'_id': u'fast_food'}, {u'count': 28, u'_id': u'community_centre'}, {u'count': 23, u'_id': u'clinic'}, {u'count': 23, u'_id': u'library'}, {u'count': 22, u'_id': u'waste_basket'}, {u'count': 21, u'_id': u'post_office'}, {u'count': 21, u'_id': u'recycling'}, {u'count': 21, u'_id': u'police'}, {u'count': 21, u'_id': u'bench'}, {u'count': 18, u'_id': u'atm'}, {u'count': 16, u'_id': u'theatre'}, {u'count': 15, u'_id': u'university'}, {u'count': 15, u'_id': u'embassy'}, {u'count': 15, u'_id': u'bus_station'}, {u'count': 14, u'_id': u'fountain'}, {u'count': 13, u'_id': u'pub'}, {u'count': 13, u'_id': u'taxi'}, {u'count': 13, u'_id': u'arts_centre'}, {u'count': 11, u'_id': u'car_wash'}, {u'count': 10, u'_id': u'post_box'}, {u'count': 10, u'_id': u'grave_yard'}, {u'count': 9, u'_id': u'swimming_pool'}, {u'count': 8, u'_id': u'cinema'}, {u'count': 8, u'_id': u'car_rental'}, {u'count': 8, u'_id': u'bureau_de_change'}, {u'count': 7, u'_id': u'dentist'}, {u'count': 6, u'_id': u'waste_disposal'}, {u'count': 5, u'_id': u'shelter'}, {u'count': 5, u'_id': u'parking_entrance'}, {u'count': 5, u'_id': u'driving_school'}, {u'count': 5, u'_id': u'childcare'}, {u'count': 5, u'_id': u'courthouse'}, {u'count': 4, u'_id': u'bar'}, {u'count': 4, u'_id': u'telephone'}, {u'count': 4, u'_id': u'veterinary'}, {u'count': 4, u'_id': u'fire_station'}, {u'count': 3, u'_id': u'internet_cafe'}, {u'count': 3, u'_id': u'marketplace'}, {u'count': 3, u'_id': u'studio'}, {u'count': 2, u'_id': u'events_venue'}, {u'count': 2, u'_id': u'shop'}, {u'count': 2, u'_id': u'bbq'}, {u'count': 2, u'_id': u'nightclub'}, {u'count': 2, u'_id': u'monastery'}, {u'count': 1, u'_id': u'parking_space'}, {u'count': 1, u'_id': u'ritual_bath'}, {u'count': 1, u'_id': u'amphitheater'}, {u'count': 1, u'_id': u'insitute'}, {u'count': 1, u'_id': u'vending_machine'}, {u'count': 1, u'_id': u'youth_centre'}, {u'count': 1, u'_id': u'0'}, {u'count': 1, u'_id': u'Archive'}, {u'count': 1, u'_id': u"children's home"}, {u'count': 1, u'_id': u'car_sharing'}, {u'count': 1, u'_id': u'retirement_home'}, {u'count': 1, u'_id': u'\u05e8\u05de\u05ea \u05d4\u05d7\u05d9\u05e0\u05d5\u05da'}, {u'count': 1, u'_id': u'social_centre'}, {u'count': 1, u'_id': u'social_facility'}, {u'count': 1, u'_id': u'NGO'}]
